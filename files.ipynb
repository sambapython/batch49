# %%
f=open("data.csv","w")

# %%
f.write("some data")

# %%
f.close()

# %%
f.write("some more data")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-9bbbad0eda73> in <module>()
# ----> 1 f.write("some more data")
#
# ValueError: I/O operation on closed file

# %%
f=open("data.csv","w")

# %%
f=open("data.csv","w")
f.write("some data\n python is a pure object oriented\n programing language")
f.write("\nPython is an interpreted high-level programming language for general-purpose programming. Created by Guido van Rossum and first released in 1991, Python has a design philosophy that emphasizes code readability, notably using significant whitespace. It provides constructs that enable clear programming on both small and large scales")
f.close()

# %%
f=open("data.csv","a")
f.write("\n writing data in append mode")
f.close()

# %%
f=open("data.csv","r")
data = f.read()
print data
# Out:
# some data
#  python is a pure object oriented
#  programing language
# Python is an interpreted high-level programming language for general-purpose programming. Created by Guido van Rossum and first released in 1991, Python has a design philosophy that emphasizes code readability, notably using significant whitespace. It provides constructs that enable clear programming on both small and large scales
#  writing data in append mode

# %%
f=open("data.csv","r")
data = f.readlines()
print data
# Out:
# ['some data\n', ' python is a pure object oriented\n', ' programing language\n', 'Python is an interpreted high-level programming language for general-purpose programming. Created by Guido van Rossum and first released in 1991, Python has a design philosophy that emphasizes code readability, notably using significant whitespace. It provides constructs that enable clear programming on both small and large scales\n', ' writing data in append mode']

# %%
f=open("data.csv","r")
print f.readline()
print f.readline()
# Out:
# some data
#
#  python is a pure object oriented

# %%
f.readline()
# Out:
# ' programing language\n'

# %%
f.readline()
# Out:
# 'Python is an interpreted high-level programming language for general-purpose programming. Created by Guido van Rossum and first released in 1991, Python has a design philosophy that emphasizes code readability, notably using significant whitespace. It provides constructs that enable clear programming on both small and large scales\n'

# %%
f=open("execution.jpg","rb")
data = f.read()
print data
# Out:
# X "��
# #B��R��$3br�
# %&'()*456789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz���������������������������������������������������������������������������
# B����	#3R�br�
# 22ǁ�.|K��m=~�_ҡ�$P���yۺ��HN�֗K��բ�i:Ɠ�鋩�:���`�����Yb ué#��P�<a�-sQ�M�|S��w��[ZjM*ԕV$Qml.nQX2�6���uh���B��_�E��!da��q���u�|6�X�������v�p���QɄ�@1��4G�m.���_�=}ݿ�C����M�}e�\j^��K��Q�v�lq��<����:�3��WK��I�iv���]��<a���(���3.���z�/ڋ�?�����)(���?��?�O�״�4���Z��O��w��d��X0E���b@�Q^�Ox����/j�%mc�Z���M���/4�YD7�,�V-&
# ${��pL��͚�+���)�'��4���������k[v�����[����r"��航~BIEbi�+���i��o�_x=�KN��j1�I�)�X��$c���
# e��g�ïx��V��m���D�7)��	��HPw4y��]�/�����W]�M���N�ݵ���i>�T����7�A,q"�2
# ĝ����_:�?~%�|]kT�5=:��ģLԵi49b�4�ru��AR�J����|�o�{mKS�Ƕ�4�'x��x�
# %p1�u�;�(���&�@�焼'����4�|M��y�xkL��_�y�����-�.�#�@JQ^'�'�"����C��,4�3�V��$iBs��I�b�/��
# ���¯����7�~x��P��+->�S��1�ȋ#h�c�H��Ǿ�QEy�x�T���K���!��DM?�-ł"ۛ�BJ���J�3s��Mz����|s��O�s�$��״;�PEw&�S�%PF�T���g�՗����Ǉ���u׍�u[����iE�$�.w7���O��v�O
# ...

# %%
f=open("execution.jpg","rb")
data = f.read()
f.close()
f=open("exe1.jpg","wb")
f.write(data)
f.close()

# %%
f=open("execution.jpg","rb")
data = f.read()
f.close()
f=open("bigfile.jpg","wb")
for i in xrange(100000):
    f.write(data)
f.close()

# %%
f=open("bigfile.jpg","rb")
data=f.read()

# %%
username=raw_input("Enter username:")
password=raw_input("enter password:")
f=open("user.csv","a")
f.write("\n%s,%s"%(username, password))
f.close()
# Out:
# Enter username:user1
# enter password:pwd1

# %%
username=raw_input("Enter username:")
password=raw_input("enter password:")
f=open("user.csv","a")
f.write("\n%s,%s"%(username, password))
f.close()
# Out:
# Enter username:user2
# enter password:pwd2

# %%
f=open("user.csv","a")
for i in xrange(3,101):
    f.write("\nuser%s,pwd%s"%(i, i))
f.close()

# %%
f=open("user.csv","r")
data=f.read()
print data
# Out:
# user1,pwd1
# user2,pwd2
# user3,pwd3
# user4,pwd4
# user5,pwd5
# user6,pwd6
# user7,pwd7
# user8,pwd8
# user9,pwd9
# user10,pwd10
# user11,pwd11
# user12,pwd12
# user13,pwd13
# user14,pwd14
# user15,pwd15
# user16,pwd16
# user17,pwd17
# user18,pwd18
# user19,pwd19
# user20,pwd20
# user21,pwd21
# user22,pwd22
# user23,pwd23
# user24,pwd24
# user25,pwd25
# user26,pwd26
# user27,pwd27
# user28,pwd28
# user29,pwd29
# user30,pwd30
# user31,pwd31
# user32,pwd32
# user33,pwd33
# user34,pwd34
# user35,pwd35
# user36,pwd36
# user37,pwd37
# user38,pwd38
# user39,pwd39
# user40,pwd40
# user41,pwd41
# user42,pwd42
# user43,pwd43
# user44,pwd44
# user45,pwd45
# user46,pwd46
# user47,pwd47
# user48,pwd48
# user49,pwd49
# user50,pwd50
# user51,pwd51
# user52,pwd52
# user53,pwd53
# user54,pwd54
# user55,pwd55
# user56,pwd56
# user57,pwd57
# user58,pwd58
# user59,pwd59
# user60,pwd60
# user61,pwd61
# user62,pwd62
# user63,pwd63
# user64,pwd64
# user65,pwd65
# user66,pwd66
# user67,pwd67
# ...

# %%
f=open("user.csv","r")
data=f.read()
data1=f.read()
print data1

# %%
f=open("user.csv","r")
print "open in read mode:",f.tell()
data=f.read()
print "after read:",f.tell()
data1=f.read()
print "second read:",f.tell()
print data1
# Out:
# open in read mode: 0
# after read: 1285
# second read: 1285

# %%
f=open("user.csv","r")
print "open in read mode:",f.tell()
data=f.read(11)
print "data:",data
print "after read:",f.tell()
data1=f.read()
print "second read:",f.tell()
print "data1: ",data1
# Out:
# open in read mode: 0
# data:
# user1,pwd1
# after read: 11
# second read: 1285
# data1:
# user2,pwd2
# user3,pwd3
# user4,pwd4
# user5,pwd5
# user6,pwd6
# user7,pwd7
# user8,pwd8
# user9,pwd9
# user10,pwd10
# user11,pwd11
# user12,pwd12
# user13,pwd13
# user14,pwd14
# user15,pwd15
# user16,pwd16
# user17,pwd17
# user18,pwd18
# user19,pwd19
# user20,pwd20
# user21,pwd21
# user22,pwd22
# user23,pwd23
# user24,pwd24
# user25,pwd25
# user26,pwd26
# user27,pwd27
# user28,pwd28
# user29,pwd29
# user30,pwd30
# user31,pwd31
# user32,pwd32
# user33,pwd33
# user34,pwd34
# user35,pwd35
# user36,pwd36
# user37,pwd37
# user38,pwd38
# user39,pwd39
# user40,pwd40
# user41,pwd41
# user42,pwd42
# user43,pwd43
# user44,pwd44
# user45,pwd45
# user46,pwd46
# user47,pwd47
# user48,pwd48
# user49,pwd49
# user50,pwd50
# user51,pwd51
# user52,pwd52
# user53,pwd53
# user54,pwd54
# user55,pwd55
# user56,pwd56
# user57,pwd57
# user58,pwd58
# user59,pwd59
# user60,pwd60
# user61,pwd61
# user62,pwd62
# ...

# %%
f=open("user.csv","r")
print "open in read mode:",f.tell()
while True:
    data=f.read(11)
    print "data:",data
    if not data:
        break
# Out:
# open in read mode: 0
# data:
# user1,pwd1
# data:
# user2,pwd2
# data:
# user3,pwd3
# data:
# user4,pwd4
# data:
# user5,pwd5
# data:
# user6,pwd6
# data:
# user7,pwd7
# data:
# user8,pwd8
# data:
# user9,pwd9
# data:
# user10,pwd
# data: 10
# user11,p
# data: wd11
# user12
# data: ,pwd12
# user
# data: 13,pwd13
# us
# data: er14,pwd14
#
# data: user15,pwd1
# data: 5
# user16,pw
# data: d16
# user17,
# data: pwd17
# user1
# data: 8,pwd18
# use
# data: r19,pwd19
# u
# data: ser20,pwd20
# data:
# user21,pwd
# data: 21
# user22,p
# data: wd22
# user23
# data: ,pwd23
# user
# data: 24,pwd24
# us
# data: er25,pwd25
#
# data: user26,pwd2
# data: 6
# user27,pw
# data: d27
# user28,
# data: pwd28
# user2
# data: 9,pwd29
# use
# data: r30,pwd30
# u
# data: ser31,pwd31
# data:
# user32,pwd
# data: 32
# user33,p
# data: wd33
# user34
# data: ,pwd34
# user
# data: 35,pwd35
# us
# data: er36,pwd36
#
# data: user37,pwd3
# data: 7
# user38,pw
# data: d38
# user39,
# data: pwd39
# user4
# ...

# %%
f=open("user.csv","r")
for i in f:
    print i
# Out:
# user1,pwd1
#
# user2,pwd2
#
# user3,pwd3
#
# user4,pwd4
#
# user5,pwd5
#
# user6,pwd6
#
# user7,pwd7
#
# user8,pwd8
#
# user9,pwd9
#
# user10,pwd10
#
# user11,pwd11
#
# user12,pwd12
#
# user13,pwd13
#
# user14,pwd14
#
# user15,pwd15
#
# user16,pwd16
#
# user17,pwd17
#
# user18,pwd18
#
# user19,pwd19
#
# user20,pwd20
#
# user21,pwd21
#
# user22,pwd22
#
# user23,pwd23
#
# user24,pwd24
#
# user25,pwd25
#
# user26,pwd26
#
# user27,pwd27
#
# user28,pwd28
#
# user29,pwd29
#
# user30,pwd30
#
# user31,pwd31
#
# user32,pwd32
#
# user33,pwd33
#
# user34,pwd34
#
# user35,pwd35
#
# user36,pwd36
#
# user37,pwd37
#
# user38,pwd38
#
# user39,pwd39
#
# user40,pwd40
#
# user41,pwd41
#
# user42,pwd42
#
# user43,pwd43
#
# user44,pwd44
#
# user45,pwd45
#
# user46,pwd46
#
# user47,pwd47
#
# user48,pwd48
#
# user49,pwd49
#
# user50,pwd50
#
# user51,pwd51
#
# user52,pwd52
#
# user53,pwd53
#
# user54,pwd54
#
# user55,pwd55
#
# user56,pwd56
#
# user57,pwd57
#
# user58,pwd58
#
# user59,pwd59
#
# user60,pwd60
# ...

# %%
f=open("user.csv","r")
print "open in read mode:",f.tell()
data=f.read()
print "after read:",f.tell()
# Out:
# open in read mode: 0
# after read: 1285

# %%
f=open("user.csv","r")
print "open in read mode:",f.tell()
data=f.read()
print "after read:",f.tell()
f.seek(100)
print "after seeking to 100 position:",f.tell()
# Out:
# open in read mode: 0
# after read: 1285
# after seeking to 100 position: 100

# %%
f=open("user.csv","r")
print "open in read mode:",f.tell()
data=f.read()
print "after read:",f.tell()
f.seek(100)
print "after seeking to 100 position:",f.tell()
data1=f.read()
print data1
# Out:
# open in read mode: 0
# after read: 1285
# after seeking to 100 position: 100
# user10,pwd10
# user11,pwd11
# user12,pwd12
# user13,pwd13
# user14,pwd14
# user15,pwd15
# user16,pwd16
# user17,pwd17
# user18,pwd18
# user19,pwd19
# user20,pwd20
# user21,pwd21
# user22,pwd22
# user23,pwd23
# user24,pwd24
# user25,pwd25
# user26,pwd26
# user27,pwd27
# user28,pwd28
# user29,pwd29
# user30,pwd30
# user31,pwd31
# user32,pwd32
# user33,pwd33
# user34,pwd34
# user35,pwd35
# user36,pwd36
# user37,pwd37
# user38,pwd38
# user39,pwd39
# user40,pwd40
# user41,pwd41
# user42,pwd42
# user43,pwd43
# user44,pwd44
# user45,pwd45
# user46,pwd46
# user47,pwd47
# user48,pwd48
# user49,pwd49
# user50,pwd50
# user51,pwd51
# user52,pwd52
# user53,pwd53
# user54,pwd54
# user55,pwd55
# user56,pwd56
# user57,pwd57
# user58,pwd58
# user59,pwd59
# user60,pwd60
# user61,pwd61
# user62,pwd62
# user63,pwd63
# user64,pwd64
# user65,pwd65
# user66,pwd66
# user67,pwd67
# user68,pwd68
# user69,pwd69
# user70,pwd70
# ...

# %%
f=open("data.yaml","r")
data=f.read()
print data
# Out:
# ---
# environment: production
# classes:
#   nfs::server:
#     exports:
#       - /srv/share1
#       - /srv/share3
# parameters:

# %%
f=open("data.yaml","r")
data=f.read()
print data
print type(data)
# Out:
# ---
# environment: production
# classes:
#   nfs::server:
#     exports:
#       - /srv/share1
#       - /srv/share3
# parameters:
#
# <type 'str'>

# %%
import yaml
f=open("data.yaml","r")
data=yaml.load(f)
print data
print type(data)
# Out:
# {'environment': 'production', 'classes': {'nfs::server': {'exports': ['/srv/share1', '/srv/share3']}}, 'parameters': None}
# <type 'dict'>

# %%
import yaml
f=open("data.yaml","r")
data=yaml.load(f)
print data
print data.keys()
# Out:
# {'environment': 'production', 'classes': {'nfs::server': {'exports': ['/srv/share1', '/srv/share3']}}, 'parameters': None}
# ['environment', 'classes', 'parameters']

# %%
import yaml
f=open("data.yaml","r")
data=yaml.load(f)
print data
print data.get("classes").keys()
# Out:
# {'environment': 'production', 'classes': {'nfs::server': {'exports': ['/srv/share1', '/srv/share3']}}, 'parameters': None}
# ['nfs::server']

# %%
import yaml
f=open("data.yaml","r")
data=yaml.load(f)
print data
print data.get("classes").get("nfs::server")
# Out:
# {'environment': 'production', 'classes': {'nfs::server': {'exports': ['/srv/share1', '/srv/share3']}}, 'parameters': None}
# {'exports': ['/srv/share1', '/srv/share3']}

# %%
import yaml
f=open("data.yaml","r")
data=yaml.load(f)
print data
print data.get("classes").get("nfs::server").get("exports")
# Out:
# {'environment': 'production', 'classes': {'nfs::server': {'exports': ['/srv/share1', '/srv/share3']}}, 'parameters': None}
# ['/srv/share1', '/srv/share3']

# %%
import json
f=open("data.json","r")
data=json.load(f)
print data
print type(data)
# Out:
# {u'glossary': {u'GlossDiv': {u'GlossList': {u'GlossEntry': {u'GlossDef': {u'GlossSeeAlso': [u'GML', u'XML'], u'para': u'A meta-markup language, used to create markup languages such as DocBook.'}, u'GlossSee': u'markup', u'Acronym': u'SGML', u'GlossTerm': u'Standard Generalized Markup Language', u'Abbrev': u'ISO 8879:1986', u'SortAs': u'SGML', u'ID': u'SGML'}}, u'title': u'S'}, u'title': u'example glossary'}}
# <type 'dict'>

# %%
import json
f=open("data.json","r")
data=f.read()
print data
# Out:
# {
#     "glossary": {
#         "title": "example glossary",
# 		"GlossDiv": {
#             "title": "S",
# 			"GlossList": {
#                 "GlossEntry": {
#                     "ID": "SGML",
# 					"SortAs": "SGML",
# 					"GlossTerm": "Standard Generalized Markup Language",
# 					"Acronym": "SGML",
# 					"Abbrev": "ISO 8879:1986",
# 					"GlossDef": {
#                         "para": "A meta-markup language, used to create markup languages such as DocBook.",
# 						"GlossSeeAlso": ["GML", "XML"]
#                     },
# 					"GlossSee": "markup"
#                 }
#             }
#         }
#     }
# }

# %%
import json
f=open("data.json","r")
data=f.read()
print data[30:60]
# Out:
# "title": "example glossary",

# %%
import json
f=open("data.json","r")
data=f.read()
print data[3]

# %%
import json
f=open("data.json","r")
data=json.load(f)
print data
# Out:
# {u'glossary': {u'GlossDiv': {u'GlossList': {u'GlossEntry': {u'GlossDef': {u'GlossSeeAlso': [u'GML', u'XML'], u'para': u'A meta-markup language, used to create markup languages such as DocBook.'}, u'GlossSee': u'markup', u'Acronym': u'SGML', u'GlossTerm': u'Standard Generalized Markup Language', u'Abbrev': u'ISO 8879:1986', u'SortAs': u'SGML', u'ID': u'SGML'}}, u'title': u'S'}, u'title': u'example glossary'}}

# %%
import json
f=open("data.json","r")
data=json.load(f)
print data, type(data)
# Out:
# {u'glossary': {u'GlossDiv': {u'GlossList': {u'GlossEntry': {u'GlossDef': {u'GlossSeeAlso': [u'GML', u'XML'], u'para': u'A meta-markup language, used to create markup languages such as DocBook.'}, u'GlossSee': u'markup', u'Acronym': u'SGML', u'GlossTerm': u'Standard Generalized Markup Language', u'Abbrev': u'ISO 8879:1986', u'SortAs': u'SGML', u'ID': u'SGML'}}, u'title': u'S'}, u'title': u'example glossary'}} <type 'dict'>

# %%
import json
f=open("data.json","r")
data=json.load(f)
print data.keys()
# Out:
# [u'glossary']

# %%
import json
f=open("data.json","r")
data=json.load(f)
print data.get("glossary")
# Out:
# {u'GlossDiv': {u'GlossList': {u'GlossEntry': {u'GlossDef': {u'GlossSeeAlso': [u'GML', u'XML'], u'para': u'A meta-markup language, used to create markup languages such as DocBook.'}, u'GlossSee': u'markup', u'Acronym': u'SGML', u'GlossTerm': u'Standard Generalized Markup Language', u'Abbrev': u'ISO 8879:1986', u'SortAs': u'SGML', u'ID': u'SGML'}}, u'title': u'S'}, u'title': u'example glossary'}

# %%
import json
f=open("data.json","r")
data=json.load(f)
print data.get("glossary").keys()
# Out:
# [u'GlossDiv', u'title']

# %%
import json
f=open("data.json","r")
data=json.load(f)
print data.get("glossary").get("title")
# Out:
# example glossary

# %%
import excel
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-37-010741c10673> in <module>()
# ----> 1 import excel
#
# ImportError: No module named excel
